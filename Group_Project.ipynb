# %% [markdown]
# <a href="https://colab.research.google.com/github/Supaporn-Bututham/data_viz_2022/blob/main/Group_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# %%
path = '/content/drive/My Drive/ Data_Group_Project'

# %% [markdown]
# ## ชุดข้อมูลรายงานจำนวนประชากร จำแนกรายจังหวัดแยกตามสถานะและสิทธิ ปีงบประมาณ 2563
#
# https://data.go.th/dataset/pop_inscl2563

# %%
covid_file_path0= os.path.join(path,'pop_maininscl_2563.csv') #โหลดชุดข้อมูลรายงานจำนวนประชากร จำแนกรายจังหวัด แยกตามสถานะและสิทธิ ปีงบประมาณ 2563
print(covid_file_path0)
# Out:
# /content/drive/My Drive/ Data_Group_Project/pop_maininscl_2563.csv

# %% [markdown]
# ## โหลดข้อมูล Covid-19 ทั้ง 4 ชุด

# %%
covid_file_path1 = os.path.join(path,'confirmed-cases.csv') #โหลดข้อมูล Covid-19 ชุดที่ 1
print(covid_file_path1)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases.csv

# %%
covid_file_path2 = os.path.join(path,'confirmed-cases-since-120864.csv') #โหลดข้อมูล Covid-19 ชุดที่ 
print(covid_file_path2)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-120864.csv

# %%
covid_file_path3 = os.path.join(path,'confirmed-cases-since-271064.csv') #โหลดข้อมูล Covid-19 ชุดที่ 3
print(covid_file_path3)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-271064.csv

# %%
covid_file_path4 = os.path.join(path,'confirmed-cases-since-280265.csv') #โหลดข้อมูล Covid-19 ชุดที่ 4
print(covid_file_path4)
# Out:
# /content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-280265.csv

# %% [markdown]
# ## ชุดข้อมูลรายงานจำนวนประชากร จำแนกรายจังหวัดแยกตามสถานะและสิทธิ ปีงบประมาณ 2563

# %%
data_file = pd.read_csv(covid_file_path0)
data_file
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-ddae87545b7d> in <module>()
# ----> 1 data_file = pd.read_csv(covid_file_path0)
#       2 data_file
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/ Data_Group_Project/pop_maininscl_2563.csv'

# %%
data_file_new = data_file.iloc[:,1:4]
data_file_new
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f1f28a2b23cc> in <module>()
# ----> 1 data_file_new = data_file.iloc[:,1:4]
#       2 data_file_new
#
# NameError: name 'data_file' is not defined

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 1

# %%
data_covid = pd.read_csv(covid_file_path1)
data_covid
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-60cf80569f1f> in <module>()
# ----> 1 data_covid = pd.read_csv(covid_file_path1)
#       2 data_covid
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/ Data_Group_Project/confirmed-cases.csv'

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 2

# %%
data_covid2 = pd.read_csv(covid_file_path2)
data_covid2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-32-b1097cc8b765> in <module>()
# ----> 1 data_covid2 = pd.read_csv(covid_file_path2)
#       2 data_covid2
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/ Data_Group_Project/confirmed-cases-since-120864.csv'

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 3

# %%
data_covid3 = pd.read_csv(covid_file_path3)
data_covid3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1e3b519b65b0> in <module>()
# ----> 1 data_covid3 = pd.read_csv(covid_file_path3)
#       2 data_covid3
#
# NameError: name 'covid_file_path3' is not defined

# %% [markdown]
# ## โหลดข้อมูลชุดที่ 4

# %%
data_covid4 = pd.read_csv(covid_file_path4)
data_covid4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# 0                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 2                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 3                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 4                      พะเยา  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# ...                      ...                                          ...
# 433548         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                             ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                             ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                             ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset
# 0                  พะเยา        เมืองพะเยา
# 1                  พะเยา        เมืองพะเยา
# 2                  พะเยา        เมืองพะเยา
# 3                  พะเยา        เมืองพะเยา
# 4                  พะเยา        เมืองพะเยา
# ...                  ...               ...
# 433548               NaN               NaN
# 433549               NaN               NaN
# 433550               NaN               NaN
# 433551               NaN               NaN
# 433552               NaN               NaN
#
# [433553 rows x 11 columns]

# %% [markdown]
# ## data region

# %%
data_region1 = { 'จังหวัด': ['อำนาจเจริญ','บึงกาฬ', 'บุรีรัมย์', 'ชัยภูมิ', 'กาฬสินธุ์', 'ขอนแก่น', 'เลย', 'มหาสารคาม', 'มุกดาหาร', 'นครพนม', 'นครราชสีมา', 'หนองบัวลำภู', 'หนองคาย', 'ร้อยเอ็ด', 'สกลนคร', 'ศรีสะเกษ', 'สุรินทร์', 'อุบลราชธานี', 'อุดรธานี', 'ยโสธร'],
             'ภูมิศาสตร์': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ'],
             'การเมือง': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ'],
             'อุตุนิยมวิทยา': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ'],
             'การท่องเที่ยว': ['ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ', 'ตะวันออกเฉียงเหนือ']
}
df_region1 = pd.DataFrame.from_dict(data_region1)
df_region1
# Out:
#         จังหวัด          ภูมิศาสตร์            การเมือง       อุตุนิยมวิทยา  \
# 0    อำนาจเจริญ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 1        บึงกาฬ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 2     บุรีรัมย์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 3       ชัยภูมิ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 4     กาฬสินธุ์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 5       ขอนแก่น  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 6           เลย  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 7     มหาสารคาม  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 8      มุกดาหาร  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 9        นครพนม  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 10   นครราชสีมา  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 11  หนองบัวลำภู  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 12      หนองคาย  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 13     ร้อยเอ็ด  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 14       สกลนคร  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 15     ศรีสะเกษ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 16     สุรินทร์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 17  อุบลราชธานี  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 18     อุดรธานี  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 19        ยโสธร  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
#
#          การท่องเที่ยว
# 0   ตะวันออกเฉียงเหนือ
# 1   ตะวันออกเฉียงเหนือ
# 2   ตะวันออกเฉียงเหนือ
# 3   ตะวันออกเฉียงเหนือ
# 4   ตะวันออกเฉียงเหนือ
# 5   ตะวันออกเฉียงเหนือ
# 6   ตะวันออกเฉียงเหนือ
# 7   ตะวันออกเฉียงเหนือ
# 8   ตะวันออกเฉียงเหนือ
# 9   ตะวันออกเฉียงเหนือ
# 10  ตะวันออกเฉียงเหนือ
# 11  ตะวันออกเฉียงเหนือ
# 12  ตะวันออกเฉียงเหนือ
# 13  ตะวันออกเฉียงเหนือ
# 14  ตะวันออกเฉียงเหนือ
# 15  ตะวันออกเฉียงเหนือ
# 16  ตะวันออกเฉียงเหนือ
# 17  ตะวันออกเฉียงเหนือ
# 18  ตะวันออกเฉียงเหนือ
# 19  ตะวันออกเฉียงเหนือ

# %%
data_region2 = { 'จังหวัด': ['เชียงใหม่', 'เชียงราย', 'ลำปาง', 'ลำพูน', 'แม่ฮ่องสอน', 'น่าน', 'พะเยา', 'แพร่', 'อุตรดิตถ์'],
             'ภูมิศาสตร์': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'การเมือง': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'อุตุนิยมวิทยา': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'การท่องเที่ยว': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ']
}
df_region2 = pd.DataFrame.from_dict(data_region2)
df_region2
# Out:
#       จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0   เชียงใหม่      เหนือ    เหนือ         เหนือ         เหนือ
# 1    เชียงราย      เหนือ    เหนือ         เหนือ         เหนือ
# 2       ลำปาง      เหนือ    เหนือ         เหนือ         เหนือ
# 3       ลำพูน      เหนือ    เหนือ         เหนือ         เหนือ
# 4  แม่ฮ่องสอน      เหนือ    เหนือ         เหนือ         เหนือ
# 5        น่าน      เหนือ    เหนือ         เหนือ         เหนือ
# 6       พะเยา      เหนือ    เหนือ         เหนือ         เหนือ
# 7        แพร่      เหนือ    เหนือ         เหนือ         เหนือ
# 8   อุตรดิตถ์      เหนือ    เหนือ         เหนือ         เหนือ

# %%
data_region3 = { 'จังหวัด': ['ตาก'],
             'ภูมิศาสตร์': ['ตะวันตก'],
             'การเมือง': ['เหนือ'],
             'อุตุนิยมวิทยา': ['เหนือ'],
             'การท่องเที่ยว': ['เหนือ']
}
df_region3 = pd.DataFrame.from_dict(data_region3)
df_region3
# Out:
#   จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0     ตาก    ตะวันตก    เหนือ         เหนือ         เหนือ

# %%
data_region4 = { 'จังหวัด': ['สุโขทัย', 'พิษณุโลก', 'พิจิตร', 'กำแพงเพชร', 'เพชรบูรณ์'],
             'ภูมิศาสตร์': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'การเมือง': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'อุตุนิยมวิทยา': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ'],
             'การท่องเที่ยว': ['เหนือ', 'เหนือ', 'เหนือ', 'เหนือ', 'เหนือ']
}
df_region4 = pd.DataFrame.from_dict(data_region4)
df_region4
# Out:
#      จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0    สุโขทัย       กลาง    เหนือ         เหนือ         เหนือ
# 1   พิษณุโลก       กลาง    เหนือ         เหนือ         เหนือ
# 2     พิจิตร       กลาง    เหนือ         เหนือ         เหนือ
# 3  กำแพงเพชร       กลาง    เหนือ         เหนือ         เหนือ
# 4  เพชรบูรณ์       กลาง    เหนือ         เหนือ         เหนือ

# %%
data_region5 = { 'จังหวัด': ['นครสวรรค์', 'อุทัยธานี'],
             'ภูมิศาสตร์': ['กลาง','กลาง'],
             'การเมือง': ['เหนือ','เหนือ'],
             'อุตุนิยมวิทยา': ['กลาง','กลาง'],
             'การท่องเที่ยว': ['เหนือ','เหนือ']
}
df_region5 = pd.DataFrame.from_dict(data_region5)
df_region5
# Out:
#      จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0  นครสวรรค์       กลาง    เหนือ          กลาง         เหนือ
# 1  อุทัยธานี       กลาง    เหนือ          กลาง         เหนือ

# %%
data_region6 = { 'จังหวัด': ['อ่างทอง', 'ชัยนาท', 'พระนครศรีอยุธยา', 'กรุงเทพมหานคร','ลพบุรี', 'นครปฐม', 'นนทบุรี', 'ปทุมธานี', 'สมุทรปราการ', 'สมุทรสาคร', 'สมุทรสงคราม', 'สระบุรี', 'สิงห์บุรี', 'สุพรรณบุรี'],
             'ภูมิศาสตร์': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'การเมือง': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'อุตุนิยมวิทยา': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'การท่องเที่ยว': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง']
}
df_region6 = pd.DataFrame.from_dict(data_region6)
df_region6
# Out:
#             จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0           อ่างทอง       กลาง     กลาง          กลาง          กลาง
# 1            ชัยนาท       กลาง     กลาง          กลาง          กลาง
# 2   พระนครศรีอยุธยา       กลาง     กลาง          กลาง          กลาง
# 3     กรุงเทพมหานคร       กลาง     กลาง          กลาง          กลาง
# 4            ลพบุรี       กลาง     กลาง          กลาง          กลาง
# 5            นครปฐม       กลาง     กลาง          กลาง          กลาง
# 6           นนทบุรี       กลาง     กลาง          กลาง          กลาง
# 7          ปทุมธานี       กลาง     กลาง          กลาง          กลาง
# 8       สมุทรปราการ       กลาง     กลาง          กลาง          กลาง
# 9         สมุทรสาคร       กลาง     กลาง          กลาง          กลาง
# 10      สมุทรสงคราม       กลาง     กลาง          กลาง          กลาง
# 11          สระบุรี       กลาง     กลาง          กลาง          กลาง
# 12        สิงห์บุรี       กลาง     กลาง          กลาง          กลาง
# 13       สุพรรณบุรี       กลาง     กลาง          กลาง          กลาง

# %%
data_region7 = { 'จังหวัด': ['นครนายก'],
             'ภูมิศาสตร์': ['กลาง'],
             'การเมือง': ['กลาง'],
             'อุตุนิยมวิทยา': ['ตะวันออก'],
             'การท่องเที่ยว': ['กลาง']
}
df_region7 = pd.DataFrame.from_dict(data_region7)
df_region7
# Out:
#    จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0  นครนายก       กลาง     กลาง      ตะวันออก          กลาง

# %%
data_region8 = { 'จังหวัด': ['ฉะเชิงเทรา', 'จันทบุรี', 'ชลบุรี', 'ปราจีนบุรี', 'ระยอง', 'สระแก้ว', 'ตราด'],
             'ภูมิศาสตร์': ['ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก'],
             'การเมือง': ['กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง', 'กลาง'],
             'อุตุนิยมวิทยา': ['ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก'],
             'การท่องเที่ยว': ['ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก', 'ตะวันออก']
}
df_region8 = pd.DataFrame.from_dict(data_region8)
df_region8
# Out:
#       จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0  ฉะเชิงเทรา   ตะวันออก     กลาง      ตะวันออก      ตะวันออก
# 1    จันทบุรี   ตะวันออก     กลาง      ตะวันออก      ตะวันออก
# 2      ชลบุรี   ตะวันออก     กลาง      ตะวันออก      ตะวันออก
# 3  ปราจีนบุรี   ตะวันออก     กลาง      ตะวันออก      ตะวันออก
# 4       ระยอง   ตะวันออก     กลาง      ตะวันออก      ตะวันออก
# 5     สระแก้ว   ตะวันออก     กลาง      ตะวันออก      ตะวันออก
# 6        ตราด   ตะวันออก     กลาง      ตะวันออก      ตะวันออก

# %%
data_region9 = { 'จังหวัด': ['กาญจนบุรี', 'ราชบุรี'],
             'ภูมิศาสตร์': ['ตะวันตก','ตะวันตก'],
             'การเมือง': ['กลาง','กลาง'],
             'อุตุนิยมวิทยา': ['กลาง','กลาง'],
             'การท่องเที่ยว': ['กลาง','กลาง']
}
df_region9 = pd.DataFrame.from_dict(data_region9)
df_region9
# Out:
#      จังหวัด ภูมิศาสตร์ การเมือง อุตุนิยมวิทยา การท่องเที่ยว
# 0  กาญจนบุรี    ตะวันตก     กลาง          กลาง          กลาง
# 1    ราชบุรี    ตะวันตก     กลาง          กลาง          กลาง

# %%
data_region10 = { 'จังหวัด': ['เพชรบุรี', 'ประจวบคีรีขันธ์'],
             'ภูมิศาสตร์': ['ตะวันตก','ตะวันตก'],
             'การเมือง': ['กลาง','กลาง'],
             'อุตุนิยมวิทยา': ['ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย','ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'],
             'การท่องเที่ยว': ['กลาง','กลาง']
}
df_region10 = pd.DataFrame.from_dict(data_region10)
df_region10
# Out:
#            จังหวัด ภูมิศาสตร์ การเมือง                   อุตุนิยมวิทยา  \
# 0         เพชรบุรี    ตะวันตก     กลาง  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 1  ประจวบคีรีขันธ์    ตะวันตก     กลาง  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
#
#   การท่องเที่ยว
# 0          กลาง
# 1          กลาง

# %%
data_region11 = { 'จังหวัด': ['ชุมพร', 'นครศรีธรรมราช','นราธิวาส', 'ปัตตานี', 'พัทลุง', 'สงขลา', 'สุราษฎร์ธานี', 'ยะลา'],
             'ภูมิศาสตร์': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'การเมือง': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'อุตุนิยมวิทยา': ['ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย', 'ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย'],
             'การท่องเที่ยว': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้']
}
df_region11 = pd.DataFrame.from_dict(data_region11)
df_region11
# Out:
#          จังหวัด ภูมิศาสตร์ การเมือง                   อุตุนิยมวิทยา  \
# 0          ชุมพร        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 1  นครศรีธรรมราช        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 2       นราธิวาส        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 3        ปัตตานี        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 4         พัทลุง        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 5          สงขลา        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 6   สุราษฎร์ธานี        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
# 7           ยะลา        ใต้      ใต้  ใต้ฝั่งตะวันออก/ใต้ฝั่งอ่าวไทย
#
#   การท่องเที่ยว
# 0           ใต้
# 1           ใต้
# 2           ใต้
# 3           ใต้
# 4           ใต้
# 5           ใต้
# 6           ใต้
# 7           ใต้

# %%
data_region12 = { 'จังหวัด': ['กระบี่', 'พังงา', 'ภูเก็ต', 'ระนอง', 'สตูล', 'ตรัง'],
             'ภูมิศาสตร์': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'การเมือง': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้'],
             'อุตุนิยมวิทยา': ['ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน', 'ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน'],
             'การท่องเที่ยว': ['ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้', 'ใต้']
}
df_region12 = pd.DataFrame.from_dict(data_region12)
df_region12
# Out:
#   จังหวัด ภูมิศาสตร์ การเมือง                   อุตุนิยมวิทยา การท่องเที่ยว
# 0  กระบี่        ใต้      ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน           ใต้
# 1   พังงา        ใต้      ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน           ใต้
# 2  ภูเก็ต        ใต้      ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน           ใต้
# 3   ระนอง        ใต้      ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน           ใต้
# 4    สตูล        ใต้      ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน           ใต้
# 5    ตรัง        ใต้      ใต้  ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน           ใต้

# %% [markdown]
# ## รวมตาราง Region

# %%
df_region_new = pd.concat([df_region1, df_region2, df_region3, df_region4, df_region5, df_region6,
                                df_region7, df_region8, df_region9, df_region10, df_region11, df_region12])  
df_region_new
# Out:
#        จังหวัด          ภูมิศาสตร์            การเมือง  \
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# ..         ...                 ...                 ...
# 1        พังงา                 ใต้                 ใต้
# 2       ภูเก็ต                 ใต้                 ใต้
# 3        ระนอง                 ใต้                 ใต้
# 4         สตูล                 ใต้                 ใต้
# 5         ตรัง                 ใต้                 ใต้
#
#                      อุตุนิยมวิทยา       การท่องเที่ยว
# 0               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 1               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 2               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 3               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# 4               ตะวันออกเฉียงเหนือ  ตะวันออกเฉียงเหนือ
# ..                             ...                 ...
# 1   ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                 ใต้
# 2   ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                 ใต้
# 3   ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                 ใต้
# 4   ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                 ใต้
# 5   ใต้ฝั่งตะวันตก/ใต้ฝั่งอันดามัน                 ใต้
#
# [77 rows x 5 columns]

# %% [markdown]
# ## รวมตารางข้อมูล Covid-19 ทั้ง 4 ชุดเข้าด้วยกัน

# %%
data_covid_new = pd.concat([data_covid, data_covid2, data_covid3, data_covid4])
data_covid_new
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# 0              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                     นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3              กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                    นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                      ...                               ...
# 433548         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433549         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433550         กรุงเทพมหานคร                  ทัณฑสถาน/เรือนจำ
# 433551                 สงขลา                  ทัณฑสถาน/เรือนจำ
# 433552                 สงขลา                  ทัณฑสถาน/เรือนจำ
#
#        province_of_onset district_of_onset  Unnamed: 11
# 0          กรุงเทพมหานคร               NaN          NaN
# 1          กรุงเทพมหานคร               NaN          NaN
# 2                 นครปฐม             เมือง          NaN
# 3          กรุงเทพมหานคร               NaN          NaN
# 4          กรุงเทพมหานคร               NaN          NaN
# ...                  ...               ...          ...
# 433548               NaN               NaN          NaN
# 433549               NaN               NaN          NaN
# 433550               NaN               NaN          NaN
# 433551               NaN               NaN          NaN
# 433552               NaN               NaN          NaN
#
# [3325951 rows x 12 columns]

# %%
df = pd.concat([data_covid_new,df_region_new,data_file_new])
df
# Out:
#        No. announce_date Notified date   sex   age Unit nationality  \
# 0      1.0     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1      2.0     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2      3.0     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3      4.0     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4      5.0     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...    ...           ...           ...   ...   ...  ...         ...
# 22747  NaN           NaN           NaN   NaN   NaN  NaN         NaN
# 22748  NaN           NaN           NaN   NaN   NaN  NaN         NaN
# 22749  NaN           NaN           NaN   NaN   NaN  NaN         NaN
# 22750  NaN           NaN           NaN   NaN   NaN  NaN         NaN
# 22751  NaN           NaN           NaN   NaN   NaN  NaN         NaN
#
#       province_of_isolation                              risk  \
# 0             กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1             กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2                    นครปฐม  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3             กรุงเทพมหานคร  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4                   นนทบุรี  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...                     ...                               ...
# 22747                   NaN                               NaN
# 22748                   NaN                               NaN
# 22749                   NaN                               NaN
# 22750                   NaN                               NaN
# 22751                   NaN                               NaN
#
#       province_of_onset district_of_onset  Unnamed: 11 จังหวัด ภูมิศาสตร์  \
# 0         กรุงเทพมหานคร               NaN          NaN     NaN        NaN
# 1         กรุงเทพมหานคร               NaN          NaN     NaN        NaN
# 2                นครปฐม             เมือง          NaN     NaN        NaN
# 3         กรุงเทพมหานคร               NaN          NaN     NaN        NaN
# 4         กรุงเทพมหานคร               NaN          NaN     NaN        NaN
# ...                 ...               ...          ...     ...        ...
# 22747               NaN               NaN          NaN     NaN        NaN
# 22748               NaN               NaN          NaN     NaN        NaN
# 22749               NaN               NaN          NaN     NaN        NaN
# 22750               NaN               NaN          NaN     NaN        NaN
# 22751               NaN               NaN          NaN     NaN        NaN
#
#       การเมือง อุตุนิยมวิทยา การท่องเที่ยว      PROVINCE_NAME       MONTH  \
# 0          NaN           NaN           NaN                NaN         NaN
# 1          NaN           NaN           NaN                NaN         NaN
# 2          NaN           NaN           NaN                NaN         NaN
# 3          NaN           NaN           NaN                NaN         NaN
# 4          NaN           NaN           NaN                NaN         NaN
# ...        ...           ...           ...                ...         ...
# 22747      NaN           NaN           NaN  กรมแพทย์ทหารอากาศ  01/05/2021
# 22748      NaN           NaN           NaN  กรมแพทย์ทหารอากาศ  01/05/2021
# 22749      NaN           NaN           NaN  กรมแพทย์ทหารอากาศ  01/05/2021
# 22750      NaN           NaN           NaN  กรมแพทย์ทหารอากาศ  01/05/2021
# 22751      NaN           NaN           NaN  กรมแพทย์ทหารอากาศ  01/05/2021
#
#                                 MAININSCL
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 22747  บุคคลคนต่างด้าว (ซื้อประกันสุขภาพ)
# 22748  บุคคลคนต่างด้าว (ซื้อประกันสุขภาพ)
# 22749                                 NaN
# 22750                                 NaN
# 22751                                 NaN
#
# [3348780 rows x 20 columns]

# %% [markdown]
# ## Data Missing

# %%
df.isnull().any() #ตรวจสอบดูว่า columns ไหนมีค่าเป็น True = missing
# Out:
# No.                      True
# announce_date            True
# Notified date            True
# sex                      True
# age                      True
# Unit                     True
# nationality              True
# province_of_isolation    True
# risk                     True
# province_of_onset        True
# district_of_onset        True
# Unnamed: 11              True
# จังหวัด                  True
# ภูมิศาสตร์               True
# การเมือง                 True
# อุตุนิยมวิทยา            True
# การท่องเที่ยว            True
# PROVINCE_NAME            True
# MONTH                    True
# MAININSCL                True
# dtype: bool

# %%
df_missing = df.fillna('ไม่มีข้อมูล') # แทนค่า missing ในทุก column  ด้วย 'ไมมีข้อมูล'
df_missing
# Out:
#                No. announce_date Notified date          sex          age  \
# 0              1.0     12/1/2020   ไม่มีข้อมูล         หญิง         61.0
# 1              2.0     17/1/2020   ไม่มีข้อมูล         หญิง         74.0
# 2              3.0     22/1/2020   ไม่มีข้อมูล         หญิง         73.0
# 3              4.0     22/1/2020   ไม่มีข้อมูล          ชาย         68.0
# 4              5.0     24/1/2020   ไม่มีข้อมูล         หญิง         66.0
# ...            ...           ...           ...          ...          ...
# 22747  ไม่มีข้อมูล   ไม่มีข้อมูล   ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล
# 22748  ไม่มีข้อมูล   ไม่มีข้อมูล   ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล
# 22749  ไม่มีข้อมูล   ไม่มีข้อมูล   ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล
# 22750  ไม่มีข้อมูล   ไม่มีข้อมูล   ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล
# 22751  ไม่มีข้อมูล   ไม่มีข้อมูล   ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล
#
#               Unit  nationality province_of_isolation  \
# 0               ปี        China         กรุงเทพมหานคร
# 1               ปี        China         กรุงเทพมหานคร
# 2               ปี     Thailand                นครปฐม
# 3               ปี        China         กรุงเทพมหานคร
# 4               ปี        China               นนทบุรี
# ...            ...          ...                   ...
# 22747  ไม่มีข้อมูล  ไม่มีข้อมูล           ไม่มีข้อมูล
# 22748  ไม่มีข้อมูล  ไม่มีข้อมูล           ไม่มีข้อมูล
# 22749  ไม่มีข้อมูล  ไม่มีข้อมูล           ไม่มีข้อมูล
# 22750  ไม่มีข้อมูล  ไม่มีข้อมูล           ไม่มีข้อมูล
# 22751  ไม่มีข้อมูล  ไม่มีข้อมูล           ไม่มีข้อมูล
#
#                                    risk province_of_onset district_of_onset  \
# 0      คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร       ไม่มีข้อมูล
# 1      คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร       ไม่มีข้อมูล
# 2      คนต่างชาติเดินทางมาจากต่างประเทศ            นครปฐม             เมือง
# 3      คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร       ไม่มีข้อมูล
# 4      คนต่างชาติเดินทางมาจากต่างประเทศ     กรุงเทพมหานคร       ไม่มีข้อมูล
# ...                                 ...               ...               ...
# 22747                       ไม่มีข้อมูล       ไม่มีข้อมูล       ไม่มีข้อมูล
# 22748                       ไม่มีข้อมูล       ไม่มีข้อมูล       ไม่มีข้อมูล
# 22749                       ไม่มีข้อมูล       ไม่มีข้อมูล       ไม่มีข้อมูล
# 22750                       ไม่มีข้อมูล       ไม่มีข้อมูล       ไม่มีข้อมูล
# 22751                       ไม่มีข้อมูล       ไม่มีข้อมูล       ไม่มีข้อมูล
#
#        Unnamed: 11      จังหวัด   ภูมิศาสตร์     การเมือง อุตุนิยมวิทยา  \
# 0      ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 1      ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 2      ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 3      ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 4      ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# ...            ...          ...          ...          ...           ...
# 22747  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 22748  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 22749  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 22750  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
# 22751  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล  ไม่มีข้อมูล   ไม่มีข้อมูล
#
#       การท่องเที่ยว      PROVINCE_NAME        MONTH  \
# 0       ไม่มีข้อมูล        ไม่มีข้อมูล  ไม่มีข้อมูล
# 1       ไม่มีข้อมูล        ไม่มีข้อมูล  ไม่มีข้อมูล
# 2       ไม่มีข้อมูล        ไม่มีข้อมูล  ไม่มีข้อมูล
# 3       ไม่มีข้อมูล        ไม่มีข้อมูล  ไม่มีข้อมูล
# 4       ไม่มีข้อมูล        ไม่มีข้อมูล  ไม่มีข้อมูล
# ...             ...                ...          ...
# 22747   ไม่มีข้อมูล  กรมแพทย์ทหารอากาศ   01/05/2021
# 22748   ไม่มีข้อมูล  กรมแพทย์ทหารอากาศ   01/05/2021
# 22749   ไม่มีข้อมูล  กรมแพทย์ทหารอากาศ   01/05/2021
# 22750   ไม่มีข้อมูล  กรมแพทย์ทหารอากาศ   01/05/2021
# 22751   ไม่มีข้อมูล  กรมแพทย์ทหารอากาศ   01/05/2021
#
#                                 MAININSCL
# 0                             ไม่มีข้อมูล
# 1                             ไม่มีข้อมูล
# 2                             ไม่มีข้อมูล
# 3                             ไม่มีข้อมูล
# 4                             ไม่มีข้อมูล
# ...                                   ...
# 22747  บุคคลคนต่างด้าว (ซื้อประกันสุขภาพ)
# 22748  บุคคลคนต่างด้าว (ซื้อประกันสุขภาพ)
# 22749                         ไม่มีข้อมูล
# 22750                         ไม่มีข้อมูล
# 22751                         ไม่มีข้อมูล
#
# [3348780 rows x 20 columns]

# %%
df_missing.isnull().any()
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# Unnamed: 11              False
# จังหวัด                  False
# ภูมิศาสตร์               False
# การเมือง                 False
# อุตุนิยมวิทยา            False
# การท่องเที่ยว            False
# PROVINCE_NAME            False
# MONTH                    False
# MAININSCL                False
# dtype: bool
