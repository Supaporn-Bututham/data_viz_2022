# %% [markdown]
# <a href="https://colab.research.google.com/github/Supaporn-Bututham/data_viz_2022/blob/main/DataViz01_Table_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://datavizcatalogue.com

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df['Name'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Parallel Coordinates
#
# เราจะเอาค่าของแต่ละค่ามา plot เทียบกัน  เพื่อดูว่าแต่ละตัวมันเหมือนหรือแตกต่างกัน
#
# https://pandas.pydata.org/docs/reference/api/pandas.plotting.parallel_coordinates.html

# %%
pd.plotting.parallel_coordinates(df,'Name')

# %% [markdown]
# ### select columns to show

# %%
pd.plotting.parallel_coordinates(df,'Name',cols = ['SepalLength','PetalLength'])

# %% [markdown]
# ####Change color

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colors.html

# %%
pd.plotting.parallel_coordinates(df,'Name',color = ['r','y','k'])

# %%
pd.plotting.parallel_coordinates(df,'Name',color = [[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]])

# %%
pd.plotting.parallel_coordinates(df,'Name',color = ['#FF00E0','#00FFE2','#ECFF00'])

# %% [markdown]
# ### Specify color by colormap

# %% [markdown]
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
pd.plotting.parallel_coordinates(df,'Name',colormap = 'Set1')

# %% [markdown]
# #Matplotlib

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib

# %% [markdown]
# ## Heatmap matrix

# %%
matplotlib.rcParams['figure.figsize']=[20,20]
plt.imshow(df.iloc[:,:-1],interpolation = 'nearest')

# %%
plt.imshow(df.iloc[:,:-1],interpolation = 'nearest',cmap = 'hot')

# %% [markdown]
# ##Subplot

# %%
matplotlib.rcParams['figure.figsize']=[10,10]

# %%
plt .subplot(1,3,1)
plt.imshow(df.iloc[:50,:-1],interpolation = 'nearest' , cmap = 'hot')

plt .subplot(1,3,2)
plt.imshow(df.iloc[50:100,:-1],interpolation = 'nearest' , cmap = 'hot')

plt .subplot(1,3,3)
plt.imshow(df.iloc[100:150,:-1],interpolation = 'nearest' , cmap = 'hot')

# %%
plt.subplot(1,4,1)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot')

plt.subplot(1,4,2)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot',alpha = 0.2)

plt.subplot(1,4,3)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot',alpha = 0.5)

plt.subplot(1,4,4)
plt.imshow(df.iloc[:50,:-1],interpolation='nearest',cmap='hot',alpha = 0.8)

# %%
plt.subplot(1,2,1)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])

plt.subplot(1,2,2)
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5],[0,0,0.8],[0.2,0.4,0.7]])

# %%
pd.plotting.parallel_coordinates(df, 'Name', color=[[0.5,0.5,0.5,0.5],[0,0,0.8,0.5],[0.2,0.4,0.7,0.5]])

# %% [markdown]
# #HW final GP1
#
# วาดกราฟ parallel coordinate เปรียบเทียบ [อายุ และ เพศ] โดยใช้ class เป็น risks (เลือกมาแค่ 3 risks)

# %% [markdown]
# ###ข้อมูลการยืนยันผู้ติดเชื้อโควิด-19

# %% [markdown]
# load data

# %%
import pandas as pd #import paddas เพื่อนำเอาไปใช้งาน

# %%
from google.colab import drive #เชื่อมต่อ colab เข้ากับไดร์ฟในข้อมูล
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os #จัดการหาไฟล์ที่อยู่ในไดร์ฟ

# %%
path = '/content/drive/My Drive/dataviz_2021_data' #ชี้ไฟล์ในไฟล์

# %%
data_con = os.path.join(path,'confirmed-cases.csv') #เอาพาร์ทที่อยู่ในไฟล์มาเชื่อมกับColab
print(data_con)
# Out:
# /content/drive/My Drive/dataviz_2021_data/confirmed-cases.csv

# %%
data_covid = pd.read_csv(data_con)  # pd.read_csv เป็นการอ่านข้อมูล แล้วตั้งชื่อตัวแปรที่เก็บไว้ว่า data_covid
data_covid
# Out:
#            No. announce_date  ... province_of_onset district_of_onset
# 0            1     12/1/2020  ...     กรุงเทพมหานคร               NaN
# 1            2     17/1/2020  ...     กรุงเทพมหานคร               NaN
# 2            3     22/1/2020  ...            นครปฐม             เมือง
# 3            4     22/1/2020  ...     กรุงเทพมหานคร               NaN
# 4            5     24/1/2020  ...     กรุงเทพมหานคร               NaN
# ...        ...           ...  ...               ...               ...
# 816984  816985     11/8/2021  ...           สระแก้ว           ตาพระยา
# 816985  816986     11/8/2021  ...           สระแก้ว           ตาพระยา
# 816986  816987     11/8/2021  ...           สระแก้ว        อรัญประเทศ
# 816987  816988     11/8/2021  ...     กรุงเทพมหานคร       บางขุนเทียน
# 816988  816989     11/8/2021  ...   พระนครศรีอยุธยา             อุทัย
#
# [816989 rows x 11 columns]

# %% [markdown]
# เลือกมาเฉพาะคอลัมน์ที่ต้องการจะวาดกราฟ

# %%
data_covid_select = data_covid[['sex','age','risk']]
data_covid_select
# Out:
#          sex   age                                               risk
# 0       หญิง  61.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       หญิง  74.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       หญิง  73.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3        ชาย  68.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       หญิง  66.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...   ...                                                ...
# 816984  หญิง   8.0                               อยู่ระหว่างการสอบสวน
# 816985   ชาย  14.0                               อยู่ระหว่างการสอบสวน
# 816986   ชาย  59.0  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 816987  หญิง  34.0                                              อื่นๆ
# 816988  หญิง  19.0                                              อื่นๆ
#
# [816989 rows x 3 columns]

# %% [markdown]
# ตรวจสอบค่า Missing

# %%
data_covid_select.isnull().any()  # .isnull() ดูค่าว่าง ถ้ามีจะแสดงเป็น  true และจากการแสดงผลพบว่าข้อมูลมีค่า Missing อยู่
# Out:
# sex     True
# age     True
# risk    True
# dtype: bool

# %% [markdown]
# แก้ค่า missing

# %%
#แทนค่า Missing ของคอลัมน์ sex ด้วยค่า Mode (ฐานนิยม)
data_covid_select['sex'].mode()  ## หาค่าที่ซ้ำกันมากที่สุดโดยใช้ .mode
# Out:
# 0    หญิง
# dtype: object

# %%
data_covid_select=data_covid_select.fillna(value ={ 'sex' : 'หญิง'})  ## แก้คอลลัมน์ sex เติมค่าว่าง โดยใช้คำสั่ง .fillna() ซึ่งค่าที่นำมาใส่คือ หญิง
data_covid_select
# Out:
#          sex   age                                               risk
# 0       หญิง  61.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       หญิง  74.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       หญิง  73.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3        ชาย  68.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       หญิง  66.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...   ...                                                ...
# 816984  หญิง   8.0                               อยู่ระหว่างการสอบสวน
# 816985   ชาย  14.0                               อยู่ระหว่างการสอบสวน
# 816986   ชาย  59.0  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 816987  หญิง  34.0                                              อื่นๆ
# 816988  หญิง  19.0                                              อื่นๆ
#
# [816989 rows x 3 columns]

# %%
set(data_covid_select['sex']) # ใช้ set ในการดูว่าในคอลัมน์ sex มีการจัดกลุ่มอย่างไร พบว่า มีการจัดกลุ่ม ที่ถูกแบ่งออกเป็น ชาย , นาย , หญิง
# Out:
# {'ชาย', 'นาย', 'หญิง'}

# %%
data_covid_select[data_covid_select['sex']=='นาย'] #เมื่อทำการแสดงข้อมูล พบว่ามีเพียงข้อมูลเดียว จึงเดาว่าน่าจะมีการผิดพลาดของข้อมูล
# Out:
#         sex   age   risk
# 377984  นาย  37.0  อื่นๆ

# %%
data_covid_select= data_covid_select.replace('นาย','ชาย') # ใช้ .replace ในการเปลี่ยนค่าข้อมูลในตาราง จาก ชาย ให้เป็น นาย

# %%
set(data_covid_select['sex']) # เมื่อที่การเซตเพื่อดูการจัดกลุ่มพบว่า เหลือแค่ค่าที่เป็นชายและหญิงเท่านั้น
# Out:
# {'ชาย', 'หญิง'}

# %%
#แทนค่า Missing ของคอลัมน์ age ด้วยค่า Mean (มัธยฐาน)
data_covid_select['age'].mean()  ## หาค่ากลางของอายุโดยใช้ .mean()
# Out:
# 35.67704043728804

# %%
data_covid_select=data_covid_select.fillna(value ={ 'age' : data_covid_select['age'].mean()})  ## แก้คอลลัมน์ age เติมค่าว่าง โดยใช้คำสั่ง .fillna() ซึ่งค่าที่นำมาใส่คือ ค่าจากค่ากลางของอายุ
data_covid_select
# Out:
#          sex   age                                               risk
# 0       หญิง  61.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       หญิง  74.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       หญิง  73.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3        ชาย  68.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       หญิง  66.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...   ...                                                ...
# 816984  หญิง   8.0                               อยู่ระหว่างการสอบสวน
# 816985   ชาย  14.0                               อยู่ระหว่างการสอบสวน
# 816986   ชาย  59.0  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 816987  หญิง  34.0                                              อื่นๆ
# 816988  หญิง  19.0                                              อื่นๆ
#
# [816989 rows x 3 columns]

# %%
#แทนค่า Missing ของคอลัมน์ risk ด้วยค่า Mode (ฐานนิยม)
data_covid_select['risk'].mode()  ## หาค่าที่ซ้ำกันมากที่สุดโดยใช้ .mode
# Out:
# 0    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# dtype: object

# %%
data_covid_select=data_covid_select.fillna(value ={ 'risk' : 'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้'})   ## แก้คอลลัมน์ risk เติมค่าว่าง โดยใช้คำสั่ง .fillna() ซึ่งค่าที่นำมาใส่คือ สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
data_covid_select
# Out:
#          sex   age                                               risk
# 0       หญิง  61.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 1       หญิง  74.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 2       หญิง  73.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 3        ชาย  68.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# 4       หญิง  66.0                   คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...   ...                                                ...
# 816984  หญิง   8.0                               อยู่ระหว่างการสอบสวน
# 816985   ชาย  14.0                               อยู่ระหว่างการสอบสวน
# 816986   ชาย  59.0  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# 816987  หญิง  34.0                                              อื่นๆ
# 816988  หญิง  19.0                                              อื่นๆ
#
# [816989 rows x 3 columns]

# %%
data_covid_select.isnull().any()  #ตรวจสอบค่า Missing
# Out:
# sex     False
# age     False
# risk    False
# dtype: bool

# %% [markdown]
# ### เลือก class ที่จะนำมาใช้ในการวาดกราฟ

# %%
data_covid_select['risk'].unique() # ดูการจัดกลุ่มของข้อมูล
# Out:
# array(['คนต่างชาติเดินทางมาจากต่างประเทศ',
#        'สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้',
#        'อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงานใกล้ชิดสัมผัสชาวต่างชาติ เป็นต้น',
#        'คนไทยเดินทางกลับจากต่างประเทศ', 'State Quarantine',
#        'บุคลากรด้านการแพทย์และสาธารณสุข',
#        'ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว', 'สถานบันเทิง',
#        'สัมผัสผู้เดินทางจากต่างประเทศ', 'สนามมวย', 'Cluster ตลาดพรพัฒน์',
#        'พิธีกรรมทางศาสนา', 'ปอดอักเสบ (Pneumonia)', 'อื่นๆ',
#        'อยู่ระหว่างการสอบสวน', 'ระบุไม่ได้',
#        'ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต',
#        'การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน',
#        'ตรวจก่อนทำหัตถการ', 'ศูนย์กักกัน ผู้ต้องกัก',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า AOQ',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า HQ/AHQ',
#        'ผู้ที่เดินทางมาจากต่างประเทศ และเข้า OQ', 'ผู้ติดเชื้อในประเทศ',
# ...

# %% [markdown]
# **technique :** https://blog.datath.com/cheatsheet-pandas/#withi_leuxk_hlay_khxlamn_cak_DataFrame

# %%
# เลือก class ที่ต้องการ
data_class = data_covid_select[(data_covid_select['risk']=='บุคลากรด้านการแพทย์และสาธารณสุข')| (data_covid_select['risk']=='พิธีกรรมทางศาสนา')|(data_covid_select['risk']=='Cluster บ่อนไก่อ่างทอง')] 
data_class
# Out:
#          sex   age                             risk
# 33      หญิง  35.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 144      ชาย  55.0                 พิธีกรรมทางศาสนา
# 145      ชาย  64.0                 พิธีกรรมทางศาสนา
# 163      ชาย  46.0                 พิธีกรรมทางศาสนา
# 164      ชาย  41.0                 พิธีกรรมทางศาสนา
# ...      ...   ...                              ...
# 815328   ชาย  24.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 815329  หญิง  28.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 815330   ชาย  30.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 816712  หญิง  25.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 816713  หญิง  30.0  บุคลากรด้านการแพทย์และสาธารณสุข
#
# [3601 rows x 3 columns]

# %%
data_class['risk'].unique() # ดูการจัดกลุ่มของข้อมูล
# Out:
# array(['บุคลากรด้านการแพทย์และสาธารณสุข', 'พิธีกรรมทางศาสนา',
#        'Cluster บ่อนไก่อ่างทอง'], dtype=object)

# %% [markdown]
# เนื่องจากจะวาดกราฟ จึงต้องแปลงค่า sex ให้เป็นตัวเลข

# %%
data_class= data_class.replace('ชาย',0)  #แทนค่าของผู้ชาย เป็นเลข 0
data_class= data_class.replace('หญิง',100) # แทนค่าของผู้หญิง เป็นเลข 70
data_class
# Out:
#         sex   age                             risk
# 33      100  35.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 144       0  55.0                 พิธีกรรมทางศาสนา
# 145       0  64.0                 พิธีกรรมทางศาสนา
# 163       0  46.0                 พิธีกรรมทางศาสนา
# 164       0  41.0                 พิธีกรรมทางศาสนา
# ...     ...   ...                              ...
# 815328    0  24.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 815329  100  28.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 815330    0  30.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 816712  100  25.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 816713  100  30.0  บุคลากรด้านการแพทย์และสาธารณสุข
#
# [3601 rows x 3 columns]

# %%
pd.plotting.parallel_coordinates(data_class,'risk',color = ['#F5DEB3','#E50000','#008000']);
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3610 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3588 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3621 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 3634 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# เนื่องจาก class ไม่สามารถแสดงเป็นภาษาไทยได้ จึงเปลี่ยนเป็นภาษาอังกฤษ

# %%
data_class= data_class.replace('บุคลากรด้านการแพทย์และสาธารณสุข','medical personnel')
data_class= data_class.replace('พิธีกรรมทางศาสนา','religious ritual')
data_class= data_class.replace('Cluster บ่อนไก่อ่างทอง','Cluster Angthong Casino')
data_class
# Out:
#         sex   age               risk
# 33      100  35.0  medical personnel
# 144       0  55.0   religious ritual
# 145       0  64.0   religious ritual
# 163       0  46.0   religious ritual
# 164       0  41.0   religious ritual
# ...     ...   ...                ...
# 815328    0  24.0  medical personnel
# 815329  100  28.0  medical personnel
# 815330    0  30.0  medical personnel
# 816712  100  25.0  medical personnel
# 816713  100  30.0  medical personnel
#
# [3601 rows x 3 columns]

# %%
pd.plotting.parallel_coordinates(data_class,'risk',color = ['#F5DEB3','#E50000','#008000']);

# %% [markdown]
# จากกราฟ
# * ทั้งชายและหญิง ที่มีความเสี่ยงจากการเป็นบุคคลากรทางการแพทย์ พบว่าอยู่ในช่วงอายุใกล้เคียงกัน
# * กลุ่มที่มีความเสี่ยงจากพิธีกรรมทางศาสนา ส่วนใหญ่จะเป็นผู้ชาย ซึ่งโดยอายุส่วนใหญ่มากกว่า 60 ปี ขึ้นไป
# * กลุ่มที่มีความเสี่ยงมาจากบ่อน มีทั้ง ชาย และหญิง โดย หญิงส่วนใหญ่จะอายุต่ำกว่า 20 ปี และชายส่วนใหญ่จะอายุ 40 ปีขึ้นไป

# %%
data_class_med = data_covid_select[(data_covid_select['risk']=='บุคลากรด้านการแพทย์และสาธารณสุข')].sort_values(by='age')
data_class_med
# Out:
#          sex   age                             risk
# 551306   ชาย   2.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 807622  หญิง   4.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 551305   ชาย   4.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 299986  หญิง   7.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 379195   ชาย   7.0  บุคลากรด้านการแพทย์และสาธารณสุข
# ...      ...   ...                              ...
# 689333   ชาย  74.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 807507  หญิง  74.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 293145  หญิง  75.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 478585   ชาย  75.0  บุคลากรด้านการแพทย์และสาธารณสุข
# 197571  หญิง  76.0  บุคลากรด้านการแพทย์และสาธารณสุข
#
# [3418 rows x 3 columns]
